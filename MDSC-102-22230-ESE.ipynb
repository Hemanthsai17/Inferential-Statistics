# %% [markdown]
# # MDSC–102(P) --> Inferential Statistics Final Lab Test

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import math

# %% [markdown]
# ## I. Answer the following. Each question carries TWO marks.

# %% [markdown]
# #### 1. How could you create a one-dimensional NumPy array of the numbers from 10 to 100, counting by 10?

# %%
np.arange(10,100,10)
# Out:
# array([10, 20, 30, 40, 50, 60, 70, 80, 90])

# %% [markdown]
# #### 2. What is the data type for 4?

# %%
dtype(4)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [93], in <cell line: 1>()
# ----> 1 dtype(4)
#
# NameError: name 'dtype' is not defined

# %% [markdown]
# #### 3. Given this code:
#
# #### What would be the value of x_array.shape? and x_array.ndim?

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
z_list=[z for z in range(0,5)]
y_list=[z_list for y in range(0,4)]
x_list=[y_list for x in range(0,3)]

x_array=np.array(x_list)
x_array.shape()
x_array.ndim()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [83], in <cell line: 6>()
#       3 x_list=[y_list for x in range(0,3)]
#       5 x_array=np.array(x_list)
# ----> 6 x_array.shape()
#       7 x_array.ndim()
#
# TypeError: 'tuple' object is not callable

# %% [markdown]
# #### 4. Write a program to generate the following output?

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### 5. For certain programs, the following is the output. What inferences you can make?

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## II. Answer the following. Each question carries THREE marks.

# %% [markdown]
# #### 6. Write a program to test the hypothesis 𝐻0: 𝜇 = 1.75 vs 𝐻1: 𝜇 ≠ 1.75 based on the following observations: 1.83, 1.83, 1.73, 1.82, 1.83, 1.73, 1.99, 1.85, 1.68, 1.87

# %% [markdown]
# #### 7. Write a program to plot the following function: 𝑓(𝑥; 𝜃) = (1 + 𝜃)𝑥𝜃 , 0 < 𝑥 < 1, 𝜃 > −1.

# %%
x=np.linspace(0,1,100)
y=[]
t=0
print("Enter the parameter theta value: (theta should be > -1)")
int(input(t))
for i in range(len(x)):
    r=(1+t)*(math.pow(x[i],t))
    y.append(r)
    
plt.plot(x,y)
# Out:
# Enter the parameter theta value: (theta should be > -1)
# 02

# %% [markdown]
# #### 8. Generate a random 100 numbers from the standard normal distribution. Plot the histogram and boxplot of the data.

# %%
x=np.random.randn(100)
mu=np.mean(x)

for j in range(len(x)):
    sum=(x[i]-mu)*(x[i]-mu)

sig=(1/100)*sum
y=[]
for i in range(len(x)):
    y.append((10*(x[i]-mu))/(sig))

plt.plot(x,y)
plt.xlim(-4,4)
# Out:
# (-4.0, 4.0)

# %% [markdown]
# #### 9. Generate pd.Series by using all the names of your classmates. Write a program to print the names containing at least 2 vowels from a series?

# %%
a=(['aaditya','reddy','satya','vamsee','hemanth','lalith','pyla','varanasi','deva','srihari','swaroop','ahar','anirudh','mathura'])
pd.Series(a)
# Out:
# 0      aaditya
# 1        reddy
# 2        satya
# 3       vamsee
# 4      hemanth
# 5       lalith
# 6         pyla
# 7     varanasi
# 8         deva
# 9      srihari
# 10     swaroop
# 11        ahar
# 12     anirudh
# 13     mathura
# dtype: object

# %% [markdown]
# #### 10. Generate random 100 integers. Write a program to find the mean, median, and standard deviation for the generated data.

# %%
sum=0
a=np.random.randint(1,100,1001)
mu=np.mean(a)
print(mu)
b=np.sort(a)
med=b[501]
print(med)

for i in range(len(a)):
    sum=(a[i]-mu)*(a[i]-mu)

stddev=(1/1000)*sum
print(stddev)
# Out:
# 48.99200799200799
# 48
# 1.4446074564795846
